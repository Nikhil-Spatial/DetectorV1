# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

# %%
from src.transforms import trainval_transforms, revert_normalization, revert_standardization
from src.dataset import ImageDataset
import torch

annot_path = Path("../data/preprocessed/trainval/annotations.csv")
img_dir = Path("../data/preprocessed/trainval/images")

# test dataset without transforms
dataset = ImageDataset(annot_path, img_dir, transform=trainval_transforms)

# %%
from src.model import Model

model = Model()
model
# Out:
# Model(
#   (backbone): ResidualBackbone(
#     (conv_1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (res_blocks): ModuleList(
#       (0): ResidualBlock(
#         (conv_1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (1-2): 2 x ResidualBlock(
#         (conv_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Identity()
#       )
#       (3): ResidualBlock(
#         (conv_1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (4): ResidualBlock(
#         (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (5-6): 2 x ResidualBlock(
#         (conv_1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Identity()
#       )
#       (7): ResidualBlock(
#         (conv_1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (8): ResidualBlock(
#         (conv_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batch_norm_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (conv_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (shortcut): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2))
#       )
#     )
#   )
#   (detector_head): DetectorHead(
#     (fc_1): Linear(in_features=25088, out_features=4096, bias=True)
#     (dropout): Identity()
#     (fc_2): Linear(in_features=4096, out_features=1225, bias=True)
#   )
# )

# %%
from torch.utils.data import DataLoader

trainval_dl = DataLoader(dataset, 8, True)

# %%
X_batch, y_batch = next(iter(trainval_dl))
X_batch.shape, y_batch.shape
# Out:
# (torch.Size([8, 3, 224, 224]), torch.Size([8, 7, 7, 25]))

# %%
preds = model(X_batch)
preds.shape
# Out:
# torch.Size([8, 7, 7, 25])

# %%
preds[0][0][0]
# Out:
# tensor([ 0.1616, -0.2349,  0.1524,  0.0590,  0.2870, -0.3515,  0.1669, -0.3917,
#         -0.1148, -0.0223, -0.1712,  0.2191, -0.4476, -0.1682,  0.0280, -0.0155,
#         -0.0216, -0.0264,  0.1019, -0.1525,  0.4987,  0.5659,  0.4703,  0.5005,
#          0.5516], grad_fn=<SelectBackward0>)
